# %% [markdown]
# Prepare data

# %%
import json
def convert_json_to_jsonl(input_file: str, output_file: str):
    # Load the JSON file
    with open(input_file, 'r', encoding='utf-8') as json_file:
        json_data = json.load(json_file)
    
    # Convert JSON to JSONL and write to output file
    with open(output_file, 'w', encoding='utf-8') as jsonl_file:
        for entry in json_data:
            jsonl_file.write(json.dumps(entry) + '\n')

input_json_file = 'data.json'  # Replace with your input file path
output_jsonl_file = 'data.jsonl'  # Replace with your output file path

convert_json_to_jsonl(input_json_file, output_jsonl_file)

# %% [markdown]
# Fine tuning teacher model

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv
load_dotenv()
api_key = os.getenv("OPENAI_API_KEY")
client = OpenAI(api_key=api_key)

# %%
# Upload Training 
training_file = client.files.create(
    file=open("data.jsonl", "rb"), purpose="fine-tune"
)
print("Training file id: ", training_file.id)
# Out:
# Training file id:  file-Ru1c5UJwxwCNVKBkze8I3I6F

# %%
# Create Fine-Tuning Job
suffix_name = "llm"
response = client.fine_tuning.jobs.create(
    training_file='file-Ru1c5UJwxwCNVKBkze8I3I6F',
    model="gpt-3.5-turbo",
    suffix=suffix_name,
)
print(response)
# Out:
# FineTuningJob(id='ftjob-9Rp36wVMvyizIpqtaFurkCW1', created_at=1727878288, error=Error(code=None, message=None, param=None), fine_tuned_model=None, finished_at=None, hyperparameters=Hyperparameters(n_epochs='auto', batch_size='auto', learning_rate_multiplier='auto'), model='gpt-3.5-turbo-0125', object='fine_tuning.job', organization_id='org-uXFhRQZlPYdmwJvwmyYmTROo', result_files=[], seed=534979875, status='validating_files', trained_tokens=None, training_file='file-Ru1c5UJwxwCNVKBkze8I3I6F', validation_file=None, estimated_finish=None, integrations=[], user_provided_suffix='llm')

# %% [markdown]
# Check Finetuning jobs

# %%
response = client.fine_tuning.jobs.retrieve("ftjob-9Rp36wVMvyizIpqtaFurkCW1")
response
# Out:
# FineTuningJob(id='ftjob-9Rp36wVMvyizIpqtaFurkCW1', created_at=1727878288, error=Error(code=None, message=None, param=None), fine_tuned_model='ft:gpt-3.5-turbo-0125:imutably-oy:llm:ADudBVBQ', finished_at=1727879315, hyperparameters=Hyperparameters(n_epochs=3, batch_size=1, learning_rate_multiplier=2), model='gpt-3.5-turbo-0125', object='fine_tuning.job', organization_id='org-uXFhRQZlPYdmwJvwmyYmTROo', result_files=['file-E8uZSc8IGReo70k5bIaSvbWJ'], seed=534979875, status='succeeded', trained_tokens=335838, training_file='file-Ru1c5UJwxwCNVKBkze8I3I6F', validation_file=None, estimated_finish=None, integrations=[], user_provided_suffix='llm')

# %%
fine_tuned_model_id = response.fine_tuned_model
print('\nFine tuned model id: ', fine_tuned_model_id)
# Out:
# Fine tuned model id:  ft:gpt-3.5-turbo-0125:imutably-oy:llm:ADudBVBQ

# %% [markdown]
# Use FineTuning Models

# %%
import csv
import os
import json
import aiohttp
import asyncio
from dotenv import load_dotenv

class HANDLER:
    @staticmethod
    def remove_empty_lines(content):
        lines = content.split("\n")
        cleaned_lines = [line.strip() for line in lines if line.strip()]
        return "\n".join(cleaned_lines)

    @staticmethod
    async def call_api_teacher(data_safety_content, privacy_policy_content, retries=3, delay=5):
        url = "https://api.openai.com/v1/chat/completions"
        
        headers = {
            "Authorization": f"Bearer {os.getenv('OPENAI_API_KEY')}",  # Use OpenAI API key
            "Content-Type": "application/json"
        }

        # Payload for OpenAI's GPT model
        payload = json.dumps({
            "model": "ft:gpt-3.5-turbo-0125:imutably-oy:llm:ADudBVBQ",  # Ensure this model ID is correct
            "temperature": 0.5,  
            "messages": [
                {
                    "role": "system",
                    "content": "You are an expert in labeling the content comparison of the Data Safety and Privacy Policy for an Android application."
                },
                {
                    "role": "user",
                    "content": f"Based on the content of the Data Safety and Privacy Policy. Please label according to the following rule:\n> Label 1: Incorrect if the content is mentioned in Data Safety but not in the Privacy Policy. Correct if the content is mentioned in both documents.\n> Label 2: Incomplete if the content is mentioned in Data Safety but not in the Privacy Policy. Complete if the content is mentioned in both documents.\nThe contents of the two documents are below.\n> Data Safety: {data_safety_content}\n> Privacy Policy: {privacy_policy_content}\nNote: The shortest answer and no explanation needed, in the format: {{label 1: Incorrect or Correct, label 2: Incomplete or Complete}}"
                }
            ]
        })

        timeout = aiohttp.ClientTimeout(total=60)  # Increase timeout to prevent premature failures

        # Retry loop
        for attempt in range(retries):
            try:
                async with aiohttp.ClientSession(timeout=timeout) as session:
                    async with session.post(url, headers=headers, data=payload) as response:
                        # Check if the response content type is JSON
                        if response.headers['Content-Type'] == 'application/json':
                            response_json = await response.json()
                            if 'error' in response_json:
                                return f"Error: {response_json['error']}"
                            
                            # Extracting the content from the message in choices array
                            content = response_json["choices"][0]["message"]["content"]
                            return content
                        else:
                            # If not JSON, read the response as text
                            response_text = await response.text()
                            return f"Unexpected response: {response_text}"
            except (aiohttp.ClientError, asyncio.TimeoutError) as e:
                print(f"Attempt {attempt + 1} failed: {e}")
                if attempt < retries - 1:
                    await asyncio.sleep(delay)  # Wait before retrying
                else:
                    return f"Error: Request failed after {retries} retries."

    @staticmethod
    async def loop_csv(input_csv_path, output_csv_path):
        with open(input_csv_path, "r", newline="", encoding="utf-8") as csvfile, open(
            output_csv_path, "w", newline="", encoding="utf-8"
        ) as outputfile:

            reader = csv.reader(csvfile)
            writer = csv.writer(outputfile)

            # Write custom header row
            writer.writerow(["App_id", "App_pkg", "Data_safety_content", "Privacy_policy_content", "Result"])

            for index, row in enumerate(reader):
                print(f"\n_____________ Run times {index + 1} <{row[0]}> _____________")
                
                # Extracting required data
                app_id = row[0]
                app_pkg = row[1]
                data_safety_content = row[3]
                privacy_policy_content = row[4]

                # Asynchronous API call with retry and timeout handling
                assistant_reply = await HANDLER.call_api_teacher(data_safety_content, privacy_policy_content)

                # Check for errors in the API response and write to CSV
                if "Error" in assistant_reply:
                    writer.writerow([app_id, app_pkg, data_safety_content, privacy_policy_content, "Error"])
                else:
                    writer.writerow([app_id, app_pkg, data_safety_content, privacy_policy_content, assistant_reply])
            
                print("~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~\n")

# %%
async def main():
    load_dotenv() 
    print(os.getcwd())
    input_csv_path = "../../data/phase-01/200v2.csv" 
    output_csv_path = "../../output/phase-01/experiment-02/output-teacher.csv"
    await HANDLER().loop_csv(input_csv_path, output_csv_path)
   

await main()
# Out:
# d:\nckh\conf-llm-nlp\src\experiment-02
#
# _____________ Run times 1 <app_id> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 2 <1> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 3 <1> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 4 <2> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 5 <3> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 6 <6> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 7 <6> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 8 <7> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 9 <31> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 10 <31> _____________
# Attempt 1 failed:
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 11 <33> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 12 <34> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 13 <34> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 14 <35> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 15 <35> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 16 <39> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 17 <40> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 18 <42> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 19 <44> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 20 <45> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 21 <46> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 22 <201> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 23 <202> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 24 <203> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 25 <203> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 26 <204> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 27 <204> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 28 <205> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 29 <207> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 30 <207> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 31 <208> _____________
# Attempt 1 failed: Cannot connect to host api.openai.com:443 ssl:default [Connect call failed ('162.159.140.245', 443)]
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 32 <209> _____________
# Attempt 1 failed: Cannot connect to host api.openai.com:443 ssl:default [Connect call failed ('172.66.0.243', 443)]
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 33 <210> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 34 <211> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 35 <212> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 36 <213> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 37 <220> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 38 <220> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 39 <225> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 40 <225> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 41 <301> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 42 <401> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 43 <402> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 44 <403> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 45 <404> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 46 <405> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 47 <406> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 48 <407> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 49 <408> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 50 <409> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 51 <410> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 52 <411> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 53 <412> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 54 <501> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 55 <502> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 56 <503> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 57 <504> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 58 <505> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 59 <506> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 60 <509> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 61 <510> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 62 <601> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 63 <602> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 64 <603> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 65 <604> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 66 <605> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 67 <606> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 68 <607> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 69 <608> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 70 <609> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 71 <611> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 72 <614> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 73 <631> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 74 <651> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 75 <652> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 76 <653> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 77 <654> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 78 <655> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 79 <656> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 80 <657> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 81 <691> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 82 <801> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 83 <802> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 84 <803> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 85 <804> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 86 <805> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 87 <806> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 88 <807> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 89 <808> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 90 <809> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 91 <810> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 92 <811> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 93 <812> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 94 <813> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 95 <814> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 96 <815> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 97 <816> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 98 <817> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 99 <818> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 100 <819> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 101 <838> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 102 <1001> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 103 <1002> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 104 <1003> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 105 <1004> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 106 <1005> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 107 <1006> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 108 <1012> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 109 <1020> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 110 <1051> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 111 <1052> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 112 <1053> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 113 <1054> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 114 <1055> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 115 <1056> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 116 <1057> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 117 <1058> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 118 <1059> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 119 <1060> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 120 <1063> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 121 <1064> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 122 <1401> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 123 <1402> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 124 <1403> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 125 <1404> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 126 <1405> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 127 <1406> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 128 <1407> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 129 <1408> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 130 <1409> _____________
# Attempt 1 failed: Cannot connect to host api.openai.com:443 ssl:default [Connect call failed ('162.159.140.245', 443)]
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 131 <1410> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 132 <1411> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 133 <1412> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 134 <1413> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 135 <1414> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 136 <1415> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 137 <1416> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 138 <1417> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 139 <1418> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 140 <1419> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 141 <1420> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 142 <1801> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 143 <1801> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 144 <1802> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 145 <1803> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 146 <1804> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 147 <1805> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 148 <1806> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 149 <1807> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 150 <1808> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 151 <1809> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 152 <1810> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 153 <1811> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 154 <1812> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 155 <1813> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 156 <1833> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 157 <1833> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 158 <1877> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 159 <1877> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 160 <1900> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 161 <1901> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 162 <2001> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 163 <2002> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 164 <2003> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 165 <2004> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 166 <2005> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 167 <2006> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 168 <2006> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 169 <2007> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 170 <2008> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 171 <2009> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 172 <2010> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 173 <2011> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 174 <2012> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 175 <2013> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 176 <2014> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 177 <2020> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 178 <2021> _____________
# Attempt 1 failed: Cannot connect to host api.openai.com:443 ssl:default [Connect call failed ('162.159.140.245', 443)]
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 179 <2023> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 180 <2024> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 181 <2025> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 182 <2201> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 183 <2202> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 184 <2203> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 185 <2204> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 186 <2205> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 187 <2206> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 188 <2207> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 189 <2208> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 190 <2209> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 191 <2210> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 192 <2211> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 193 <2212> _____________
# Attempt 1 failed: Cannot connect to host api.openai.com:443 ssl:default [Connect call failed ('162.159.140.245', 443)]
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 194 <2213> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 195 <2214> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 196 <2215> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 197 <2216> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 198 <2217> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 199 <2227> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 200 <2232> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
#
#
# _____________ Run times 201 <2289> _____________
# ~~~~~~~~~~~~~~ Success ~~~~~~~~~~~~~~
